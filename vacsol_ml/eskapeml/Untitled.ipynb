# %%
import pickletools

with open("eskape_ensemble_model.pkl", "rb") as f:
    pickletools.dis(f)
# Out:
#     0: \x80 PROTO      4
#     2: \x95 FRAME      920
#    11: }    EMPTY_DICT
#    12: \x94 MEMOIZE    (as 0)
#    13: (    MARK
#    14: \x8c     SHORT_BINUNICODE 'Random_Forest'
#    29: \x94     MEMOIZE    (as 1)
#    30: \x8c     SHORT_BINUNICODE 'sklearn.ensemble._forest'
#    56: \x94     MEMOIZE    (as 2)
#    57: \x8c     SHORT_BINUNICODE 'RandomForestClassifier'
#    81: \x94     MEMOIZE    (as 3)
#    82: \x93     STACK_GLOBAL
#    83: \x94     MEMOIZE    (as 4)
#    84: )        EMPTY_TUPLE
#    85: \x81     NEWOBJ
#    86: \x94     MEMOIZE    (as 5)
#    87: }        EMPTY_DICT
#    88: \x94     MEMOIZE    (as 6)
#    89: (        MARK
#    90: \x8c         SHORT_BINUNICODE 'estimator'
#   101: \x94         MEMOIZE    (as 7)
#   102: \x8c         SHORT_BINUNICODE 'sklearn.tree._classes'
#   125: \x94         MEMOIZE    (as 8)
#   126: \x8c         SHORT_BINUNICODE 'DecisionTreeClassifier'
#   150: \x94         MEMOIZE    (as 9)
#   151: \x93         STACK_GLOBAL
# ...
